# %% [markdown]
# <a href="https://colab.research.google.com/github/lritinab/Data612FrankClass/blob/main/Brown_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/frankData612/data_612/master/stock_data/stocks_yahoo.csv')

# %%
df.head(20)
# Out:
#     no         date  ... Dividend Yield 1Y target est
# 0    1  Nov 21 2019  ...      N/A (N/A)      1,487.52
# 1    2  Nov 21 2019  ...      N/A (N/A)      1,459.33
# 2    3  Nov 21 2019  ...   6.48 (4.86%)         148.3
# 3    4  Nov 21 2019  ...   2.04 (1.36%)        160.16
# 4    5  Nov 21 2019  ...   3.08 (1.16%)        257.21
# 5    6  Nov 21 2019  ...      N/A (N/A)      2,183.86
# 6    7  Nov 21 2019  ...      N/A (N/A)           NaN
# 7    8  Nov 21 2019  ...   0.96 (1.70%)         56.27
# 8    9  Nov 21 2019  ...      N/A (N/A)          66.4
# 9   10  Nov 21 2019  ...   3.60 (2.78%)        123.71
# 10  11  Nov 21 2019  ...   1.68 (2.84%)         57.77
# 11  12  Nov 21 2019  ...   2.80 (3.06%)         97.07
# 12  13  Nov 21 2019  ...   0.68 (1.52%)          43.2
# 13  14  Nov 21 2019  ...   3.84 (3.23%)        125.21
# 14  15  Nov 21 2019  ...      N/A (N/A)         44.76
# 15  16  Nov 21 2019  ...      N/A (N/A)         67.96
# 16  17  Nov 21 2019  ...   0.98 (1.05%)        102.07
# 17  18  Nov 21 2019  ...   8.22 (2.22%)        379.95
# 18  19  Nov 21 2019  ...   3.48 (5.12%)         79.02
# 19  20  Nov 21 2019  ...   3.16 (8.21%)         51.55
#
# [20 rows x 19 columns]

# %%
df.tail(15)
# Out:
#           no         date  ... Dividend Yield 1Y target est
# 67890  67891  Apr 28 2020  ...      N/A (N/A)          45.5
# 67891  67892  Apr 28 2020  ...   0.04 (0.34%)         60.52
# 67892  67893  Apr 28 2020  ...      N/A (N/A)            82
# 67893  67894  Apr 28 2020  ...      N/A (N/A)         29.67
# 67894  67895  Apr 28 2020  ...      N/A (N/A)         58.33
# 67895  67896  Apr 28 2020  ...      N/A (N/A)        137.25
# 67896  67897  Apr 28 2020  ...   0.64 (2.95%)            24
# 67897  67898  Apr 28 2020  ...   0.32 (1.21%)         34.13
# 67898  67899  Apr 28 2020  ...      N/A (N/A)            28
# 67899  67900  Apr 28 2020  ...      N/A (N/A)         66.75
# 67900  67901  Apr 28 2020  ...      N/A (N/A)         12.83
# 67901  67902  Apr 28 2020  ...   0.44 (1.49%)         33.33
# 67902  67903  Apr 28 2020  ...      N/A (N/A)          11.5
# 67903  67904  Apr 28 2020  ...      N/A (N/A)         67.67
# 67904  67905  Apr 28 2020  ...      N/A (N/A)         67.62
#
# [15 rows x 19 columns]

# %%
df.columns
# Out:
# Index(['no', 'date', 'company_name', 'price_at_close', 'price_change',
#        'price_after_hours', 'previous_close', 'today opened', 'price range',
#        '52 week range', 'volume', 'average volume', 'market cap',
#        'beta (3Y Monthly)', 'PE Ratio', 'EPS', 'earnings date',
#        'Dividend Yield', '1Y target est'],
#       dtype='object')

# %%
df.dtypes
# Out:
# no                     int64
# date                  object
# company_name          object
# price_at_close        object
# price_change          object
# price_after_hours     object
# previous_close        object
# today opened          object
# price range           object
# 52 week range         object
# volume                object
# average volume        object
# market cap            object
# beta (3Y Monthly)    float64
# PE Ratio              object
# EPS                   object
# earnings date         object
# Dividend Yield        object
# 1Y target est         object
# dtype: object

# %%
df.shape
# Out:
# (67905, 19)

# %%
df.groupby('date')['beta (3Y Monthly)'].mean()
# Out:
# date
# Apr 01 2020    1.364849
# Apr 02 2020    1.190114
# Apr 03 2020    1.189886
# Apr 06 2020    1.376509
# Apr 07 2020    1.317920
#                  ...
# Mar 30 2020    1.197909
# Mar 31 2020    1.365340
# Nov 21 2019    1.032083
# Nov 22 2019    1.182526
# Nov 25 2019    0.670298
# Name: beta (3Y Monthly), Length: 90, dtype: float64
